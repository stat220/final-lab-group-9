# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

df = pd.read_csv('https://richardson.byu.edu/220/OnlineNewsPopularity.csv')

df.columns = df.columns.str.strip()

target = 'shares'

# %% [markdown]
# EDA

# %%
# Plot target variable
plt.figure(figsize=(10, 6))
sns.histplot(df[target], kde=True, bins=30, color='blue')
plt.title('Distribution of Shares', fontsize=14)
plt.xlabel('Shares', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print(df[target].describe())
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %%
# Due to highly skewed, Log-transform the target variable to reduce skewness
df['log_shares'] = np.log1p(df['shares'])

plt.figure(figsize=(10, 6))
sns.histplot(df['log_shares'], kde=True, bins=30, color='green')
plt.title('Distribution of Log-Transformed Shares', fontsize=14)
plt.xlabel('Log(Shares)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

target = 'log_shares'

# %%
# Initial Linear Regression Model
X = df.drop(columns=['log_shares', 'url', 'shares'])
y = df[target]

# Keep numeric columns
X = X.select_dtypes(include=[np.number])

X_const = sm.add_constant(X)
ols_model = sm.OLS(y, X_const).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_shares   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     101.0
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:32:07   Log-Likelihood:                -50668.
# No. Observations:               39644   AIC:                         1.015e+05
# Df Residuals:                   39586   BIC:                         1.020e+05
# Df Model:                          57
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                           -23.1377    393.869     -0.059      0.953    -795.130     748.855
# timedelta                      6.184e-05   2.97e-05      2.084      0.037    3.69e-06       0.000
# n_tokens_title                    0.0081      0.002      3.689      0.000       0.004       0.012
# n_tokens_content               4.061e-05   1.69e-05      2.404      0.016     7.5e-06    7.37e-05
# n_unique_tokens                   0.1623      0.145      1.116      0.264      -0.123       0.447
# n_non_stop_words                  0.0760      0.447      0.170      0.865      -0.800       0.952
# n_non_stop_unique_tokens         -0.2421      0.123     -1.964      0.050      -0.484      -0.001
# num_hrefs                         0.0042      0.001      8.296      0.000       0.003       0.005
# num_self_hrefs                   -0.0080      0.001     -5.926      0.000      -0.011      -0.005
# num_imgs                          0.0024      0.001      3.582      0.000       0.001       0.004
# num_videos                        0.0019      0.001      1.619      0.105      -0.000       0.004
# average_token_length             -0.0918      0.018     -4.996      0.000      -0.128      -0.056
# num_keywords                      0.0119      0.003      4.251      0.000       0.006       0.017
# data_channel_is_lifestyle        -0.1022      0.030     -3.421      0.001      -0.161      -0.044
# data_channel_is_entertainment    -0.1795      0.019     -9.266      0.000      -0.218      -0.142
# data_channel_is_bus              -0.1651      0.029     -5.707      0.000      -0.222      -0.108
# data_channel_is_socmed            0.1610      0.028      5.712      0.000       0.106       0.216
# data_channel_is_tech              0.1029      0.028      3.660      0.000       0.048       0.158
# data_channel_is_world            -0.0382      0.029     -1.337      0.181      -0.094       0.018
# kw_min_min                        0.0009      0.000      7.229      0.000       0.001       0.001
# kw_max_min                     1.706e-05   3.81e-06      4.481      0.000     9.6e-06    2.45e-05
# kw_avg_min                       -0.0001   2.34e-05     -5.443      0.000      -0.000   -8.15e-05
# kw_min_max                    -3.521e-07    8.9e-08     -3.955      0.000   -5.27e-07   -1.78e-07
# kw_max_max                     5.053e-08   4.46e-08      1.133      0.257   -3.69e-08    1.38e-07
# kw_avg_max                    -2.868e-07   6.41e-08     -4.473      0.000   -4.13e-07   -1.61e-07
# kw_min_avg                    -5.048e-05   5.72e-06     -8.826      0.000   -6.17e-05   -3.93e-05
# kw_max_avg                    -4.187e-05   1.91e-06    -21.885      0.000   -4.56e-05   -3.81e-05
# kw_avg_avg                        0.0003   1.09e-05     30.786      0.000       0.000       0.000
# self_reference_min_shares      7.392e-07   5.69e-07      1.299      0.194   -3.76e-07    1.85e-06
# self_reference_max_shares     -9.711e-10   3.09e-07     -0.003      0.997   -6.06e-07    6.04e-07
# self_reference_avg_sharess      1.44e-06   7.89e-07      1.825      0.068   -1.07e-07    2.99e-06
# weekday_is_monday                -4.0764     69.506     -0.059      0.953    -140.310     132.158
# weekday_is_tuesday               -4.1440     69.506     -0.060      0.952    -140.378     132.090
# weekday_is_wednesday             -4.1404     69.506     -0.060      0.952    -140.374     132.093
# weekday_is_thursday              -4.1349     69.506     -0.059      0.953    -140.369     132.099
# weekday_is_friday                -4.0714     69.506     -0.059      0.953    -140.305     132.163
# weekday_is_saturday              -1.2836     23.169     -0.055      0.956     -46.695      44.128
# weekday_is_sunday                -1.2871     23.169     -0.056      0.956     -46.698      44.124
# is_weekend                       -2.5707     46.337     -0.055      0.956     -93.393      88.252
# LDA_00                           34.0488    463.374      0.073      0.941    -874.176     942.273
# LDA_01                           33.6808    463.374      0.073      0.942    -874.542     941.904
# LDA_02                           33.5927    463.374      0.072      0.942    -874.631     941.817
# LDA_03                           33.7013    463.373      0.073      0.942    -874.521     941.924
# LDA_04                           33.8276    463.374      0.073      0.942    -874.396     942.051
# global_subjectivity               0.4081      0.064      6.348      0.000       0.282       0.534
# global_sentiment_polarity        -0.1120      0.126     -0.889      0.374      -0.359       0.135
# global_rate_positive_words       -1.1582      0.542     -2.138      0.033      -2.220      -0.097
# global_rate_negative_words        0.4825      1.034      0.466      0.641      -1.545       2.510
# rate_positive_words               0.2767      0.437      0.634      0.526      -0.579       1.132
# rate_negative_words               0.1243      0.440      0.283      0.778      -0.738       0.987
# avg_positive_polarity             0.0035      0.103      0.034      0.973      -0.199       0.206
# min_positive_polarity            -0.2724      0.086     -3.150      0.002      -0.442      -0.103
# max_positive_polarity            -0.0262      0.033     -0.803      0.422      -0.090       0.038
# avg_negative_polarity            -0.1477      0.095     -1.553      0.121      -0.334       0.039
# min_negative_polarity             0.0048      0.035      0.139      0.890      -0.063       0.073
# max_negative_polarity             0.0839      0.079      1.060      0.289      -0.071       0.239
# title_subjectivity                0.0589      0.021      2.843      0.004       0.018       0.100
# title_sentiment_polarity          0.0815      0.019      4.307      0.000       0.044       0.119
# abs_title_subjectivity            0.1418      0.028      5.154      0.000       0.088       0.196
# abs_title_sentiment_polarity      0.0265      0.030      0.886      0.376      -0.032       0.085
# ==============================================================================
# Omnibus:                     7299.849   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19786.699
# Skew:                           0.995   Prob(JB):                         0.00
# Kurtosis:                       5.831   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.51e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Higher-Order Terms
from sklearn.preprocessing import PolynomialFeatures

# Add higher-order terms (polynomial and interaction terms)
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

X_poly_df = pd.DataFrame(X_poly, columns=poly.get_feature_names_out(X.columns))

X_poly_const = sm.add_constant(X_poly_df)

ols_poly_model = sm.OLS(y, X_poly_const).fit()
print(ols_poly_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_shares   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     12.09
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:32:24   Log-Likelihood:                -48583.
# No. Observations:               39644   AIC:                         9.892e+04
# Df Residuals:                   38769   BIC:                         1.064e+05
# Df Model:                         874
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.2116      0.252      4.808      0.000       0.718       1.706
# timedelta                                                      0.0060      0.001      9.254      0.000       0.005       0.007
# n_tokens_title                                                 0.0175      0.024      0.727      0.467      -0.030       0.065
# n_tokens_content                                               0.0012      0.002      0.704      0.482      -0.002       0.004
# n_unique_tokens                                               -0.5378      1.229     -0.438      0.662      -2.947       1.871
# n_non_stop_words                                               0.4299      0.465      0.925      0.355      -0.481       1.341
# n_non_stop_unique_tokens                                       0.2643      1.092      0.242      0.809      -1.877       2.406
# num_hrefs                                                      0.0228      0.005      4.421      0.000       0.013       0.033
# num_self_hrefs                                                -0.0478      0.016     -2.898      0.004      -0.080      -0.015
# num_imgs                                                      -0.0015      0.008     -0.193      0.847      -0.016       0.014
# num_videos                                                     0.0079      0.020      0.386      0.700      -0.032       0.048
# average_token_length                                          -0.2369      0.150     -1.581      0.114      -0.531       0.057
# num_keywords                                                   0.0859      0.033      2.570      0.010       0.020       0.151
# data_channel_is_lifestyle                                      0.1224      0.167      0.732      0.464      -0.206       0.450
# data_channel_is_entertainment                                 -0.1392      0.108     -1.290      0.197      -0.351       0.072
# data_channel_is_bus                                           -0.2179      0.164     -1.326      0.185      -0.540       0.104
# data_channel_is_socmed                                        -0.0789      0.166     -0.475      0.635      -0.405       0.247
# data_channel_is_tech                                           0.2868      0.154      1.858      0.063      -0.016       0.589
# data_channel_is_world                                          0.0374      0.146      0.256      0.798      -0.249       0.324
# kw_min_min                                                     0.0097      0.003      3.403      0.001       0.004       0.015
# kw_max_min                                                 -5.401e-05   8.51e-05     -0.635      0.526      -0.000       0.000
# kw_avg_min                                                    -0.0002      0.000     -0.485      0.628      -0.001       0.001
# kw_min_max                                                 -5.766e-06   1.89e-05     -0.305      0.760   -4.28e-05    3.13e-05
# kw_max_max                                                    -0.0002      0.000     -0.617      0.537      -0.001       0.000
# kw_avg_max                                                 -5.313e-05      0.000     -0.405      0.685      -0.000       0.000
# kw_min_avg                                                    -0.0001    9.2e-05     -1.550      0.121      -0.000    3.77e-05
# kw_max_avg                                                  9.432e-06   5.41e-05      0.174      0.862   -9.66e-05       0.000
# kw_avg_avg                                                     0.0001      0.000      0.763      0.446      -0.000       0.000
# self_reference_min_shares                                      0.0008      0.009      0.098      0.922      -0.016       0.018
# self_reference_max_shares                                  -1.509e-05      0.004     -0.004      0.997      -0.008       0.008
# self_reference_avg_sharess                                     0.0047      0.012      0.406      0.685      -0.018       0.028
# weekday_is_monday                                              0.2910      0.078      3.731      0.000       0.138       0.444
# weekday_is_tuesday                                             0.1836      0.079      2.324      0.020       0.029       0.338
# weekday_is_wednesday                                           0.1199      0.077      1.551      0.121      -0.032       0.271
# weekday_is_thursday                                            0.1327      0.078      1.711      0.087      -0.019       0.285
# weekday_is_friday                                              0.3024      0.081      3.745      0.000       0.144       0.461
# weekday_is_saturday                                            0.1438      0.065      2.220      0.026       0.017       0.271
# weekday_is_sunday                                              0.0390      0.062      0.633      0.527      -0.082       0.160
# is_weekend                                                     0.1827      0.055      3.346      0.001       0.076       0.290
# LDA_00                                                         0.2545      0.294      0.865      0.387      -0.322       0.831
# LDA_01                                                        -0.0551      0.233     -0.236      0.813      -0.512       0.402
# LDA_02                                                         0.4602      0.282      1.630      0.103      -0.093       1.013
# LDA_03                                                         0.2288      0.216      1.061      0.289      -0.194       0.652
# LDA_04                                                         0.3237      0.256      1.263      0.207      -0.179       0.826
# global_subjectivity                                            0.5258      0.548      0.960      0.337      -0.547       1.599
# global_sentiment_polarity                                     -0.9848      0.996     -0.989      0.323      -2.937       0.967
# global_rate_positive_words                                    -1.8903      1.648     -1.147      0.251      -5.120       1.339
# global_rate_negative_words                                    -0.6386      0.691     -0.924      0.355      -1.993       0.715
# rate_positive_words                                            0.5187      0.274      1.892      0.059      -0.019       1.056
# rate_negative_words                                           -0.0872      0.366     -0.238      0.812      -0.804       0.630
# avg_positive_polarity                                         -0.4010      0.898     -0.447      0.655      -2.161       1.359
# min_positive_polarity                                          0.3583      0.734      0.488      0.625      -1.080       1.797
# max_positive_polarity                                          0.4946      0.316      1.567      0.117      -0.124       1.113
# avg_negative_polarity                                          1.5606      0.931      1.677      0.094      -0.264       3.385
# min_negative_polarity                                         -0.3023      0.355     -0.851      0.395      -0.998       0.394
# max_negative_polarity                                         -0.6656      0.744     -0.895      0.371      -2.124       0.793
# title_subjectivity                                             0.2298      0.181      1.272      0.203      -0.124       0.584
# title_sentiment_polarity                                       0.2371      0.194      1.223      0.221      -0.143       0.617
# abs_title_subjectivity                                         0.3731      0.297      1.256      0.209      -0.209       0.955
# abs_title_sentiment_polarity                                   0.0290      0.316      0.092      0.927      -0.591       0.649
# timedelta^2                                                -1.897e-06   2.53e-07     -7.504      0.000   -2.39e-06    -1.4e-06
# timedelta n_tokens_title                                    1.919e-05   1.51e-05      1.266      0.205   -1.05e-05    4.89e-05
# timedelta n_tokens_content                                  2.801e-07    1.3e-07      2.154      0.031    2.52e-08    5.35e-07
# timedelta n_unique_tokens                                     -0.0010      0.001     -1.020      0.308      -0.003       0.001
# timedelta n_non_stop_words                                     0.0002      0.001      0.130      0.897      -0.002       0.003
# timedelta n_non_stop_unique_tokens                             0.0014      0.001      1.626      0.104      -0.000       0.003
# timedelta num_hrefs                                        -5.637e-06   3.76e-06     -1.500      0.134    -1.3e-05    1.73e-06
# timedelta num_self_hrefs                                   -9.904e-06    1.1e-05     -0.903      0.366   -3.14e-05    1.16e-05
# timedelta num_imgs                                         -2.202e-06   5.31e-06     -0.415      0.678   -1.26e-05    8.21e-06
# timedelta num_videos                                        3.056e-05   9.37e-06      3.262      0.001    1.22e-05    4.89e-05
# timedelta average_token_length                              2.746e-05      0.000      0.218      0.827      -0.000       0.000
# timedelta num_keywords                                        -0.0001   2.01e-05     -7.034      0.000      -0.000      -0.000
# timedelta data_channel_is_lifestyle                            0.0006      0.000      2.792      0.005       0.000       0.001
# timedelta data_channel_is_entertainment                        0.0001      0.000      0.762      0.446      -0.000       0.000
# timedelta data_channel_is_bus                                 -0.0003      0.000     -1.269      0.205      -0.001       0.000
# timedelta data_channel_is_socmed                               0.0002      0.000      0.836      0.403      -0.000       0.001
# timedelta data_channel_is_tech                                -0.0002      0.000     -0.952      0.341      -0.001       0.000
# timedelta data_channel_is_world                            -6.148e-05      0.000     -0.310      0.757      -0.000       0.000
# timedelta kw_min_min                                       -2.157e-05   4.76e-06     -4.536      0.000   -3.09e-05   -1.23e-05
# timedelta kw_max_min                                       -5.622e-08   4.85e-08     -1.160      0.246   -1.51e-07    3.88e-08
# timedelta kw_avg_min                                        3.678e-07   3.03e-07      1.215      0.225   -2.26e-07    9.61e-07
# timedelta kw_min_max                                       -1.439e-09   8.31e-10     -1.733      0.083   -3.07e-09    1.88e-10
# timedelta kw_max_max                                       -8.459e-09   8.38e-10    -10.091      0.000   -1.01e-08   -6.82e-09
# timedelta kw_avg_max                                       -1.099e-09   4.96e-10     -2.214      0.027   -2.07e-09   -1.26e-10
# timedelta kw_min_avg                                       -2.367e-08   4.06e-08     -0.584      0.559   -1.03e-07    5.58e-08
# timedelta kw_max_avg                                       -9.211e-09   1.71e-08     -0.540      0.589   -4.27e-08    2.42e-08
# timedelta kw_avg_avg                                        1.151e-07   8.43e-08      1.365      0.172   -5.02e-08     2.8e-07
# timedelta self_reference_min_shares                        -7.407e-09   7.84e-09     -0.945      0.345   -2.28e-08    7.95e-09
# timedelta self_reference_max_shares                        -5.248e-09   4.33e-09     -1.212      0.225   -1.37e-08    3.24e-09
# timedelta self_reference_avg_sharess                        1.993e-08   1.11e-08      1.790      0.073   -1.89e-09    4.17e-08
# timedelta weekday_is_monday                                    0.0011      0.000      5.136      0.000       0.001       0.001
# timedelta weekday_is_tuesday                                   0.0012      0.000      5.741      0.000       0.001       0.002
# timedelta weekday_is_wednesday                                 0.0012      0.000      5.772      0.000       0.001       0.002
# timedelta weekday_is_thursday                                  0.0012      0.000      5.986      0.000       0.001       0.002
# timedelta weekday_is_friday                                    0.0011      0.000      5.518      0.000       0.001       0.002
# timedelta weekday_is_saturday                                  0.0004      0.000      3.440      0.001       0.000       0.001
# timedelta weekday_is_sunday                                    0.0004      0.000      3.286      0.001       0.000       0.001
# timedelta is_weekend                                           0.0007      0.000      5.263      0.000       0.000       0.001
# timedelta LDA_00                                               0.0016      0.000      5.832      0.000       0.001       0.002
# timedelta LDA_01                                               0.0011      0.000      3.973      0.000       0.001       0.002
# timedelta LDA_02                                               0.0012      0.000      4.430      0.000       0.001       0.002
# timedelta LDA_03                                               0.0014      0.000      5.271      0.000       0.001       0.002
# timedelta LDA_04                                               0.0012      0.000      4.209      0.000       0.001       0.002
# timedelta global_subjectivity                                  0.0005      0.000      1.209      0.227      -0.000       0.001
# timedelta global_sentiment_polarity                            0.0012      0.001      1.348      0.178      -0.001       0.003
# timedelta global_rate_positive_words                          -0.0042      0.004     -1.127      0.260      -0.012       0.003
# timedelta global_rate_negative_words                           0.0025      0.007      0.352      0.725      -0.012       0.017
# timedelta rate_positive_words                                 -0.0006      0.001     -0.431      0.667      -0.003       0.002
# timedelta rate_negative_words                               5.427e-05      0.001      0.036      0.971      -0.003       0.003
# timedelta avg_positive_polarity                               -0.0005      0.001     -0.758      0.448      -0.002       0.001
# timedelta min_positive_polarity                               -0.0002      0.001     -0.367      0.713      -0.001       0.001
# timedelta max_positive_polarity                                0.0001      0.000      0.514      0.607      -0.000       0.001
# timedelta avg_negative_polarity                                0.0002      0.001      0.327      0.744      -0.001       0.001
# timedelta min_negative_polarity                                0.0002      0.000      1.005      0.315      -0.000       0.001
# timedelta max_negative_polarity                               -0.0008      0.001     -1.618      0.106      -0.002       0.000
# timedelta title_subjectivity                                   0.0002      0.000      1.093      0.275      -0.000       0.000
# timedelta title_sentiment_polarity                          3.418e-05      0.000      0.266      0.790      -0.000       0.000
# timedelta abs_title_subjectivity                               0.0004      0.000      2.084      0.037    2.29e-05       0.001
# timedelta abs_title_sentiment_polarity                        -0.0002      0.000     -0.772      0.440      -0.001       0.000
# n_tokens_title^2                                               0.0015      0.001      1.962      0.050    1.25e-06       0.003
# n_tokens_title n_tokens_content                            -2.887e-06   8.04e-06     -0.359      0.720   -1.86e-05    1.29e-05
# n_tokens_title n_unique_tokens                                -0.0069      0.071     -0.096      0.923      -0.147       0.133
# n_tokens_title n_non_stop_words                               -0.0557      0.036     -1.539      0.124      -0.127       0.015
# n_tokens_title n_non_stop_unique_tokens                        0.0274      0.061      0.450      0.653      -0.092       0.147
# n_tokens_title num_hrefs                                      -0.0005      0.000     -1.797      0.072      -0.001     4.4e-05
# n_tokens_title num_self_hrefs                                 -0.0014      0.001     -1.953      0.051      -0.003    5.44e-06
# n_tokens_title num_imgs                                       -0.0002      0.000     -0.534      0.593      -0.001       0.000
# n_tokens_title num_videos                                      0.0002      0.001      0.338      0.735      -0.001       0.002
# n_tokens_title average_token_length                            0.0145      0.009      1.587      0.112      -0.003       0.032
# n_tokens_title num_keywords                                   -0.0008      0.001     -0.567      0.571      -0.004       0.002
# n_tokens_title data_channel_is_lifestyle                       0.0080      0.015      0.524      0.600      -0.022       0.038
# n_tokens_title data_channel_is_entertainment                  -0.0243      0.010     -2.466      0.014      -0.044      -0.005
# n_tokens_title data_channel_is_bus                            -0.0241      0.014     -1.707      0.088      -0.052       0.004
# n_tokens_title data_channel_is_socmed                         -0.0145      0.014     -1.045      0.296      -0.042       0.013
# n_tokens_title data_channel_is_tech                           -0.0100      0.014     -0.716      0.474      -0.037       0.017
# n_tokens_title data_channel_is_world                          -0.0099      0.014     -0.696      0.487      -0.038       0.018
# n_tokens_title kw_min_min                                     -0.0001   6.33e-05     -2.316      0.021      -0.000   -2.26e-05
# n_tokens_title kw_max_min                                  -5.314e-06   3.36e-06     -1.582      0.114   -1.19e-05    1.27e-06
# n_tokens_title kw_avg_min                                   3.713e-05   2.01e-05      1.844      0.065   -2.34e-06    7.66e-05
# n_tokens_title kw_min_max                                   2.868e-08   4.58e-08      0.626      0.531   -6.11e-08    1.18e-07
# n_tokens_title kw_max_max                                  -3.225e-08   2.26e-08     -1.426      0.154   -7.66e-08    1.21e-08
# n_tokens_title kw_avg_max                                   8.601e-08   3.29e-08      2.611      0.009    2.15e-08    1.51e-07
# n_tokens_title kw_min_avg                                   2.342e-07   2.96e-06      0.079      0.937   -5.56e-06    6.03e-06
# n_tokens_title kw_max_avg                                   1.573e-06    1.2e-06      1.313      0.189   -7.75e-07    3.92e-06
# n_tokens_title kw_avg_avg                                  -8.448e-06   6.08e-06     -1.390      0.164   -2.04e-05    3.46e-06
# n_tokens_title self_reference_min_shares                   -4.553e-07    4.9e-07     -0.929      0.353   -1.42e-06    5.05e-07
# n_tokens_title self_reference_max_shares                    1.158e-07   2.86e-07      0.405      0.686   -4.45e-07    6.76e-07
# n_tokens_title self_reference_avg_sharess                   6.365e-08   7.18e-07      0.089      0.929   -1.34e-06    1.47e-06
# n_tokens_title weekday_is_monday                               0.0062      0.006      0.971      0.332      -0.006       0.019
# n_tokens_title weekday_is_tuesday                              0.0071      0.006      1.129      0.259      -0.005       0.019
# n_tokens_title weekday_is_wednesday                           -0.0013      0.006     -0.215      0.830      -0.014       0.011
# n_tokens_title weekday_is_thursday                            -0.0026      0.006     -0.418      0.676      -0.015       0.010
# n_tokens_title weekday_is_friday                               0.0008      0.007      0.126      0.900      -0.012       0.014
# n_tokens_title weekday_is_saturday                            -0.0033      0.007     -0.482      0.630      -0.017       0.010
# n_tokens_title weekday_is_sunday                               0.0116      0.006      1.778      0.075      -0.001       0.024
# n_tokens_title is_weekend                                      0.0083      0.005      1.686      0.092      -0.001       0.018
# n_tokens_title LDA_00                                         -0.0053      0.013     -0.397      0.691      -0.031       0.021
# n_tokens_title LDA_01                                          0.0225      0.012      1.854      0.064      -0.001       0.046
# n_tokens_title LDA_02                                         -0.0037      0.013     -0.283      0.777      -0.029       0.022
# n_tokens_title LDA_03                                          0.0122      0.011      1.083      0.279      -0.010       0.034
# n_tokens_title LDA_04                                         -0.0074      0.012     -0.595      0.552      -0.032       0.017
# n_tokens_title global_subjectivity                             0.0354      0.032      1.115      0.265      -0.027       0.098
# n_tokens_title global_sentiment_polarity                       0.0033      0.063      0.053      0.958      -0.120       0.127
# n_tokens_title global_rate_positive_words                     -0.1513      0.264     -0.573      0.567      -0.669       0.366
# n_tokens_title global_rate_negative_words                     -0.1296      0.510     -0.254      0.799      -1.130       0.870
# n_tokens_title rate_positive_words                            -0.0356      0.025     -1.403      0.160      -0.085       0.014
# n_tokens_title rate_negative_words                            -0.0200      0.030     -0.668      0.504      -0.079       0.039
# n_tokens_title avg_positive_polarity                          -0.0242      0.052     -0.468      0.640      -0.126       0.077
# n_tokens_title min_positive_polarity                           0.0226      0.043      0.528      0.597      -0.061       0.106
# n_tokens_title max_positive_polarity                          -0.0079      0.016     -0.488      0.626      -0.040       0.024
# n_tokens_title avg_negative_polarity                           0.0042      0.048      0.088      0.930      -0.089       0.098
# n_tokens_title min_negative_polarity                          -0.0047      0.017     -0.270      0.787      -0.039       0.029
# n_tokens_title max_negative_polarity                          -0.0464      0.040     -1.163      0.245      -0.124       0.032
# n_tokens_title title_subjectivity                             -0.0080      0.010     -0.771      0.441      -0.028       0.012
# n_tokens_title title_sentiment_polarity                       -0.0026      0.010     -0.270      0.787      -0.021       0.016
# n_tokens_title abs_title_subjectivity                          0.0052      0.014      0.375      0.708      -0.022       0.033
# n_tokens_title abs_title_sentiment_polarity                   -0.0084      0.015     -0.569      0.569      -0.037       0.021
# n_tokens_content^2                                         -4.481e-08   1.77e-08     -2.537      0.011   -7.94e-08   -1.02e-08
# n_tokens_content n_unique_tokens                              -0.0024      0.001     -3.885      0.000      -0.004      -0.001
# n_tokens_content n_non_stop_words                             -0.0022      0.003     -0.745      0.456      -0.008       0.004
# n_tokens_content n_non_stop_unique_tokens                      0.0010      0.000      2.220      0.026       0.000       0.002
# n_tokens_content num_hrefs                                 -1.444e-06   1.26e-06     -1.149      0.251   -3.91e-06    1.02e-06
# n_tokens_content num_self_hrefs                             -9.16e-07   4.12e-06     -0.222      0.824   -8.99e-06    7.16e-06
# n_tokens_content num_imgs                                  -6.814e-07   1.27e-06     -0.536      0.592   -3.17e-06    1.81e-06
# n_tokens_content num_videos                                 3.557e-06   4.42e-06      0.805      0.421    -5.1e-06    1.22e-05
# n_tokens_content average_token_length                          0.0002   7.97e-05      2.199      0.028     1.9e-05       0.000
# n_tokens_content num_keywords                                 4.8e-07   1.12e-05      0.043      0.966   -2.14e-05    2.24e-05
# n_tokens_content data_channel_is_lifestyle                     0.0001      0.000      0.944      0.345      -0.000       0.000
# n_tokens_content data_channel_is_entertainment              3.767e-05   9.63e-05      0.391      0.696      -0.000       0.000
# n_tokens_content data_channel_is_bus                        6.612e-06      0.000      0.051      0.959      -0.000       0.000
# n_tokens_content data_channel_is_socmed                       -0.0002      0.000     -1.595      0.111      -0.000     4.5e-05
# n_tokens_content data_channel_is_tech                      -1.693e-06      0.000     -0.014      0.989      -0.000       0.000
# n_tokens_content data_channel_is_world                        -0.0001      0.000     -0.906      0.365      -0.000       0.000
# n_tokens_content kw_min_min                                -9.668e-08   6.36e-07     -0.152      0.879   -1.34e-06    1.15e-06
# n_tokens_content kw_max_min                                 1.994e-08   2.94e-08      0.678      0.498   -3.77e-08    7.76e-08
# n_tokens_content kw_avg_min                                -1.702e-07   1.85e-07     -0.921      0.357   -5.32e-07    1.92e-07
# n_tokens_content kw_min_max                                 8.031e-10   4.99e-10      1.610      0.107   -1.74e-10    1.78e-09
# n_tokens_content kw_max_max                                 2.107e-10   2.21e-10      0.955      0.340   -2.22e-10    6.43e-10
# n_tokens_content kw_avg_max                                -3.682e-10   2.94e-10     -1.250      0.211   -9.45e-10    2.09e-10
# n_tokens_content kw_min_avg                                 4.375e-08   2.34e-08      1.872      0.061   -2.06e-09    8.96e-08
# n_tokens_content kw_max_avg                                 4.496e-09   9.34e-09      0.482      0.630   -1.38e-08    2.28e-08
# n_tokens_content kw_avg_avg                                -3.769e-08   4.96e-08     -0.760      0.447   -1.35e-07    5.95e-08
# n_tokens_content self_reference_min_shares                  5.901e-09    5.2e-09      1.135      0.256   -4.29e-09    1.61e-08
# n_tokens_content self_reference_max_shares                 -3.302e-10   2.66e-09     -0.124      0.901   -5.55e-09    4.89e-09
# n_tokens_content self_reference_avg_sharess                -2.144e-09   7.32e-09     -0.293      0.770   -1.65e-08    1.22e-08
# n_tokens_content weekday_is_monday                         -2.111e-05      0.000     -0.066      0.947      -0.001       0.001
# n_tokens_content weekday_is_tuesday                            0.0002      0.000      0.609      0.542      -0.000       0.001
# n_tokens_content weekday_is_wednesday                          0.0003      0.000      0.783      0.433      -0.000       0.001
# n_tokens_content weekday_is_thursday                           0.0001      0.000      0.429      0.668      -0.000       0.001
# n_tokens_content weekday_is_friday                          5.411e-05      0.000      0.170      0.865      -0.001       0.001
# n_tokens_content weekday_is_saturday                        4.118e-05      0.000      0.357      0.721      -0.000       0.000
# n_tokens_content weekday_is_sunday                          6.389e-05      0.000      0.568      0.570      -0.000       0.000
# n_tokens_content is_weekend                                    0.0001      0.000      0.494      0.621      -0.000       0.001
# n_tokens_content LDA_00                                        0.0003      0.000      0.704      0.481      -0.000       0.001
# n_tokens_content LDA_01                                        0.0002      0.000      0.493      0.622      -0.001       0.001
# n_tokens_content LDA_02                                     9.381e-05      0.000      0.252      0.801      -0.001       0.001
# n_tokens_content LDA_03                                     5.946e-05      0.000      0.162      0.871      -0.001       0.001
# n_tokens_content LDA_04                                        0.0001      0.000      0.328      0.743      -0.001       0.001
# n_tokens_content global_subjectivity                          -0.0005      0.000     -1.439      0.150      -0.001       0.000
# n_tokens_content global_sentiment_polarity                    -0.0008      0.001     -1.012      0.312      -0.002       0.001
# n_tokens_content global_rate_positive_words                   -0.0001      0.003     -0.052      0.958      -0.005       0.005
# n_tokens_content global_rate_negative_words                   -0.0009      0.005     -0.192      0.847      -0.010       0.008
# n_tokens_content rate_positive_words                           0.0005      0.001      0.643      0.520      -0.001       0.002
# n_tokens_content rate_negative_words                           0.0001      0.001      0.195      0.845      -0.001       0.002
# n_tokens_content avg_positive_polarity                         0.0011      0.001      1.950      0.051   -5.41e-06       0.002
# n_tokens_content min_positive_polarity                        -0.0007      0.001     -1.372      0.170      -0.002       0.000
# n_tokens_content max_positive_polarity                        -0.0002      0.000     -0.974      0.330      -0.001       0.000
# n_tokens_content avg_negative_polarity                        -0.0003      0.000     -0.722      0.470      -0.001       0.001
# n_tokens_content min_negative_polarity                     -5.821e-05      0.000     -0.422      0.673      -0.000       0.000
# n_tokens_content max_negative_polarity                         0.0012      0.000      2.552      0.011       0.000       0.002
# n_tokens_content title_subjectivity                          8.76e-05   8.15e-05      1.074      0.283   -7.22e-05       0.000
# n_tokens_content title_sentiment_polarity                    8.56e-05   8.12e-05      1.054      0.292   -7.36e-05       0.000
# n_tokens_content abs_title_subjectivity                     4.716e-05      0.000      0.443      0.658      -0.000       0.000
# n_tokens_content abs_title_sentiment_polarity                  0.0001      0.000      1.014      0.311      -0.000       0.000
# n_unique_tokens^2                                             -0.9950      1.309     -0.760      0.447      -3.560       1.570
# n_unique_tokens n_non_stop_words                              -0.5395      1.229     -0.439      0.661      -2.948       1.869
# n_unique_tokens n_non_stop_unique_tokens                       1.3872      1.306      1.062      0.288      -1.173       3.948
# n_unique_tokens num_hrefs                                      0.0040      0.019      0.217      0.828      -0.032       0.041
# n_unique_tokens num_self_hrefs                                -0.1186      0.058     -2.031      0.042      -0.233      -0.004
# n_unique_tokens num_imgs                                      -0.0055      0.024     -0.223      0.823      -0.053       0.042
# n_unique_tokens num_videos                                    -0.0082      0.048     -0.171      0.864      -0.101       0.085
# n_unique_tokens average_token_length                           0.8512      0.510      1.669      0.095      -0.148       1.851
# n_unique_tokens num_keywords                                  -0.1011      0.094     -1.080      0.280      -0.285       0.082
# n_unique_tokens data_channel_is_lifestyle                      0.3357      0.986      0.340      0.734      -1.597       2.269
# n_unique_tokens data_channel_is_entertainment                  0.3839      0.626      0.613      0.540      -0.843       1.611
# n_unique_tokens data_channel_is_bus                            0.2934      0.954      0.308      0.758      -1.576       2.163
# n_unique_tokens data_channel_is_socmed                        -0.6487      0.882     -0.736      0.462      -2.377       1.079
# n_unique_tokens data_channel_is_tech                          -0.4697      0.925     -0.508      0.611      -2.282       1.343
# n_unique_tokens data_channel_is_world                          0.5067      0.943      0.538      0.591      -1.341       2.355
# n_unique_tokens kw_min_min                                    -0.0038      0.004     -0.914      0.361      -0.012       0.004
# n_unique_tokens kw_max_min                                  1.429e-06      0.000      0.006      0.995      -0.000       0.000
# n_unique_tokens kw_avg_min                                  2.482e-05      0.001      0.017      0.987      -0.003       0.003
# n_unique_tokens kw_min_max                                  8.582e-07   3.11e-06      0.276      0.783   -5.24e-06    6.96e-06
# n_unique_tokens kw_max_max                                 -7.859e-07    1.5e-06     -0.522      0.601   -3.74e-06    2.16e-06
# n_unique_tokens kw_avg_max                                 -1.004e-06   2.18e-06     -0.460      0.646   -5.28e-06    3.28e-06
# n_unique_tokens kw_min_avg                                 -7.025e-05      0.000     -0.370      0.711      -0.000       0.000
# n_unique_tokens kw_max_avg                                  3.324e-05   7.44e-05      0.447      0.655      -0.000       0.000
# n_unique_tokens kw_avg_avg                                    -0.0002      0.000     -0.462      0.644      -0.001       0.001
# n_unique_tokens self_reference_min_shares                   7.674e-07   3.68e-05      0.021      0.983   -7.13e-05    7.28e-05
# n_unique_tokens self_reference_max_shares                  -3.864e-05   2.43e-05     -1.589      0.112   -8.63e-05    9.02e-06
# n_unique_tokens self_reference_avg_sharess                  6.582e-05   5.74e-05      1.147      0.251   -4.66e-05       0.000
# n_unique_tokens weekday_is_monday                             -0.5443      0.393     -1.386      0.166      -1.314       0.226
# n_unique_tokens weekday_is_tuesday                             0.3948      0.373      1.058      0.290      -0.337       1.127
# n_unique_tokens weekday_is_wednesday                          -0.2756      0.376     -0.734      0.463      -1.012       0.460
# n_unique_tokens weekday_is_thursday                            0.0558      0.380      0.147      0.883      -0.688       0.800
# n_unique_tokens weekday_is_friday                             -0.5959      0.407     -1.465      0.143      -1.393       0.202
# n_unique_tokens weekday_is_saturday                            0.4676      0.454      1.031      0.303      -0.422       1.357
# n_unique_tokens weekday_is_sunday                             -0.0406      0.412     -0.098      0.922      -0.848       0.767
# n_unique_tokens is_weekend                                     0.4270      0.298      1.433      0.152      -0.157       1.011
# n_unique_tokens LDA_00                                        -0.3642      0.884     -0.412      0.680      -2.097       1.368
# n_unique_tokens LDA_01                                         1.0711      0.781      1.372      0.170      -0.459       2.602
# n_unique_tokens LDA_02                                        -0.5295      0.902     -0.587      0.557      -2.297       1.238
# n_unique_tokens LDA_03                                        -0.1748      0.719     -0.243      0.808      -1.585       1.235
# n_unique_tokens LDA_04                                        -0.5408      0.818     -0.661      0.508      -2.143       1.062
# n_unique_tokens global_subjectivity                           -1.3592      1.990     -0.683      0.495      -5.259       2.541
# n_unique_tokens global_sentiment_polarity                     -6.2802      3.285     -1.912      0.056     -12.720       0.159
# n_unique_tokens global_rate_positive_words                     1.2898      2.068      0.624      0.533      -2.764       5.344
# n_unique_tokens global_rate_negative_words                     0.3660      0.980      0.374      0.709      -1.554       2.286
# n_unique_tokens rate_positive_words                           -0.0099      1.033     -0.010      0.992      -2.034       2.014
# n_unique_tokens rate_negative_words                           -0.5282      1.158     -0.456      0.648      -2.798       1.741
# n_unique_tokens avg_positive_polarity                          5.4486      3.083      1.767      0.077      -0.594      11.492
# n_unique_tokens min_positive_polarity                          0.2643      2.450      0.108      0.914      -4.537       5.066
# n_unique_tokens max_positive_polarity                         -0.7186      1.121     -0.641      0.521      -2.916       1.479
# n_unique_tokens avg_negative_polarity                         -0.2735      3.200     -0.085      0.932      -6.545       5.998
# n_unique_tokens min_negative_polarity                         -0.5547      1.242     -0.447      0.655      -2.989       1.880
# n_unique_tokens max_negative_polarity                          2.5849      2.588      0.999      0.318      -2.487       7.657
# n_unique_tokens title_subjectivity                             0.8530      0.692      1.233      0.218      -0.503       2.209
# n_unique_tokens title_sentiment_polarity                       0.5794      0.620      0.935      0.350      -0.636       1.795
# n_unique_tokens abs_title_subjectivity                         0.7145      0.891      0.802      0.422      -1.031       2.460
# n_unique_tokens abs_title_sentiment_polarity                  -0.1358      1.002     -0.136      0.892      -2.099       1.827
# n_non_stop_words^2                                             0.4297      0.463      0.929      0.353      -0.477       1.337
# n_non_stop_words n_non_stop_unique_tokens                      0.2633      1.093      0.241      0.810      -1.878       2.405
# n_non_stop_words num_hrefs                                     0.0231      0.005      4.450      0.000       0.013       0.033
# n_non_stop_words num_self_hrefs                               -0.0490      0.016     -2.970      0.003      -0.081      -0.017
# n_non_stop_words num_imgs                                     -0.0145      0.011     -1.321      0.187      -0.036       0.007
# n_non_stop_words num_videos                                   -0.0212      0.032     -0.672      0.501      -0.083       0.041
# n_non_stop_words average_token_length                         -0.2372      0.150     -1.583      0.114      -0.531       0.057
# n_non_stop_words num_keywords                                 -0.0517      0.048     -1.069      0.285      -0.146       0.043
# n_non_stop_words data_channel_is_lifestyle                    -0.7396      0.501     -1.476      0.140      -1.722       0.243
# n_non_stop_words data_channel_is_entertainment                -0.1346      0.319     -0.422      0.673      -0.759       0.490
# n_non_stop_words data_channel_is_bus                           0.5239      0.485      1.079      0.280      -0.427       1.475
# n_non_stop_words data_channel_is_socmed                        1.2452      0.477      2.609      0.009       0.310       2.181
# n_non_stop_words data_channel_is_tech                         -0.1656      0.463     -0.358      0.721      -1.073       0.742
# n_non_stop_words data_channel_is_world                         0.4995      0.470      1.064      0.287      -0.421       1.420
# n_non_stop_words kw_min_min                                    0.0018      0.002      0.829      0.407      -0.003       0.006
# n_non_stop_words kw_max_min                                   -0.0002      0.001     -0.127      0.899      -0.003       0.003
# n_non_stop_words kw_avg_min                                    0.0003      0.001      0.245      0.807      -0.002       0.003
# n_non_stop_words kw_min_max                                    0.0005      0.003      0.201      0.841      -0.005       0.006
# n_non_stop_words kw_max_max                                   -0.0005      0.002     -0.197      0.844      -0.005       0.004
# n_non_stop_words kw_avg_max                                    0.0009      0.005      0.193      0.847      -0.008       0.010
# n_non_stop_words kw_min_avg                                    0.0010      0.007      0.142      0.887      -0.013       0.015
# n_non_stop_words kw_max_avg                                    0.0027      0.005      0.521      0.603      -0.007       0.013
# n_non_stop_words kw_avg_avg                                    0.0014      0.006      0.246      0.806      -0.010       0.012
# n_non_stop_words self_reference_min_shares                     0.0025      0.008      0.322      0.748      -0.013       0.018
# n_non_stop_words self_reference_max_shares                     0.0013      0.006      0.226      0.821      -0.010       0.012
# n_non_stop_words self_reference_avg_sharess                   -0.0061      0.010     -0.634      0.526      -0.025       0.013
# n_non_stop_words weekday_is_monday                             0.1683      0.184      0.913      0.361      -0.193       0.530
# n_non_stop_words weekday_is_tuesday                            0.1402      0.176      0.797      0.425      -0.205       0.485
# n_non_stop_words weekday_is_wednesday                          0.1939      0.176      1.101      0.271      -0.151       0.539
# n_non_stop_words weekday_is_thursday                           0.1484      0.177      0.841      0.401      -0.198       0.494
# n_non_stop_words weekday_is_friday                            -0.1533      0.190     -0.805      0.421      -0.526       0.220
# n_non_stop_words weekday_is_saturday                           0.0799      0.225      0.354      0.723      -0.362       0.522
# n_non_stop_words weekday_is_sunday                            -0.1458      0.210     -0.696      0.487      -0.557       0.265
# n_non_stop_words is_weekend                                   -0.0660      0.143     -0.462      0.644      -0.346       0.214
# n_non_stop_words LDA_00                                       -0.1791      0.455     -0.394      0.694      -1.070       0.712
# n_non_stop_words LDA_01                                        0.2214      0.409      0.542      0.588      -0.580       1.023
# n_non_stop_words LDA_02                                        0.2726      0.444      0.614      0.539      -0.597       1.142
# n_non_stop_words LDA_03                                        0.2232      0.371      0.601      0.548      -0.505       0.951
# n_non_stop_words LDA_04                                       -0.1065      0.396     -0.269      0.788      -0.882       0.669
# n_non_stop_words global_subjectivity                           0.5259      0.548      0.960      0.337      -0.547       1.599
# n_non_stop_words global_sentiment_polarity                    -0.9848      0.996     -0.989      0.323      -2.937       0.967
# n_non_stop_words global_rate_positive_words                   -1.8903      1.648     -1.147      0.251      -5.120       1.339
# n_non_stop_words global_rate_negative_words                   -0.6386      0.691     -0.924      0.355      -1.993       0.715
# n_non_stop_words rate_positive_words                           0.5187      0.274      1.892      0.059      -0.019       1.056
# n_non_stop_words rate_negative_words                          -0.0871      0.366     -0.238      0.812      -0.804       0.630
# n_non_stop_words avg_positive_polarity                        -0.4010      0.898     -0.447      0.655      -2.161       1.359
# n_non_stop_words min_positive_polarity                         0.3583      0.734      0.488      0.625      -1.080       1.797
# n_non_stop_words max_positive_polarity                         0.4946      0.316      1.567      0.117      -0.124       1.113
# n_non_stop_words avg_negative_polarity                         1.5606      0.931      1.677      0.094      -0.264       3.385
# n_non_stop_words min_negative_polarity                        -0.3024      0.355     -0.851      0.394      -0.998       0.394
# n_non_stop_words max_negative_polarity                        -0.6656      0.744     -0.895      0.371      -2.124       0.793
# n_non_stop_words title_subjectivity                           -0.6091      0.350     -1.738      0.082      -1.296       0.078
# n_non_stop_words title_sentiment_polarity                     -0.1404      0.327     -0.429      0.668      -0.782       0.501
# n_non_stop_words abs_title_subjectivity                       -1.0538      0.458     -2.301      0.021      -1.951      -0.156
# n_non_stop_words abs_title_sentiment_polarity                  0.0325      0.512      0.064      0.949      -0.970       1.036
# n_non_stop_unique_tokens^2                                    -0.5750      1.038     -0.554      0.580      -2.609       1.459
# n_non_stop_unique_tokens num_hrefs                            -0.0181      0.015     -1.240      0.215      -0.047       0.010
# n_non_stop_unique_tokens num_self_hrefs                        0.0577      0.047      1.240      0.215      -0.034       0.149
# n_non_stop_unique_tokens num_imgs                              0.0219      0.020      1.110      0.267      -0.017       0.061
# n_non_stop_unique_tokens num_videos                           -0.0125      0.042     -0.295      0.768      -0.095       0.070
# n_non_stop_unique_tokens average_token_length                 -0.4870      0.429     -1.136      0.256      -1.327       0.353
# n_non_stop_unique_tokens num_keywords                         -0.0409      0.079     -0.517      0.605      -0.196       0.114
# n_non_stop_unique_tokens data_channel_is_lifestyle             0.2695      0.828      0.325      0.745      -1.354       1.892
# n_non_stop_unique_tokens data_channel_is_entertainment        -0.0658      0.523     -0.126      0.900      -1.092       0.960
# n_non_stop_unique_tokens data_channel_is_bus                   0.2774      0.812      0.342      0.733      -1.315       1.870
# n_non_stop_unique_tokens data_channel_is_socmed               -0.4644      0.777     -0.598      0.550      -1.988       1.059
# n_non_stop_unique_tokens data_channel_is_tech                  0.9564      0.774      1.236      0.217      -0.561       2.474
# n_non_stop_unique_tokens data_channel_is_world                 0.0762      0.781      0.098      0.922      -1.454       1.607
# n_non_stop_unique_tokens kw_min_min                            0.0032      0.004      0.910      0.363      -0.004       0.010
# n_non_stop_unique_tokens kw_max_min                            0.0001      0.000      0.673      0.501      -0.000       0.001
# n_non_stop_unique_tokens kw_avg_min                           -0.0009      0.001     -0.766      0.444      -0.003       0.001
# n_non_stop_unique_tokens kw_min_max                        -7.133e-07   2.78e-06     -0.256      0.798   -6.17e-06    4.74e-06
# n_non_stop_unique_tokens kw_max_max                         1.179e-06   1.27e-06      0.925      0.355   -1.32e-06    3.68e-06
# n_non_stop_unique_tokens kw_avg_max                         6.286e-10   1.82e-06      0.000      1.000   -3.57e-06    3.57e-06
# n_non_stop_unique_tokens kw_min_avg                            0.0001      0.000      0.760      0.447      -0.000       0.000
# n_non_stop_unique_tokens kw_max_avg                        -3.664e-05   5.92e-05     -0.619      0.536      -0.000    7.93e-05
# n_non_stop_unique_tokens kw_avg_avg                            0.0002      0.000      0.776      0.438      -0.000       0.001
# n_non_stop_unique_tokens self_reference_min_shares          8.553e-06   2.87e-05      0.298      0.766   -4.78e-05    6.49e-05
# ...
# global_sentiment_polarity^2                                   -0.9441      1.231     -0.767      0.443      -3.357       1.469
# global_sentiment_polarity global_rate_positive_words          -1.8094      2.085     -0.868      0.385      -5.895       2.276
# global_sentiment_polarity global_rate_negative_words           0.2878      1.093      0.263      0.792      -1.854       2.430
# global_sentiment_polarity rate_positive_words                  0.3888      0.809      0.480      0.631      -1.198       1.975
# global_sentiment_polarity rate_negative_words                 -1.3736      0.863     -1.591      0.112      -3.065       0.318
# global_sentiment_polarity avg_positive_polarity               -2.1989      2.182     -1.008      0.314      -6.475       2.077
# global_sentiment_polarity min_positive_polarity                0.5283      1.579      0.335      0.738      -2.566       3.623
# global_sentiment_polarity max_positive_polarity                0.6321      0.902      0.701      0.484      -1.136       2.400
# global_sentiment_polarity avg_negative_polarity                0.4926      2.686      0.183      0.854      -4.771       5.756
# global_sentiment_polarity min_negative_polarity               -0.5949      1.149     -0.518      0.605      -2.847       1.657
# global_sentiment_polarity max_negative_polarity               -0.3150      1.927     -0.163      0.870      -4.092       3.462
# global_sentiment_polarity title_subjectivity                  -0.4506      0.570     -0.790      0.429      -1.568       0.667
# global_sentiment_polarity title_sentiment_polarity            -0.6192      0.504     -1.228      0.219      -1.607       0.369
# global_sentiment_polarity abs_title_subjectivity               0.1245      0.736      0.169      0.866      -1.317       1.566
# global_sentiment_polarity abs_title_sentiment_polarity         1.2205      0.791      1.544      0.123      -0.329       2.770
# global_rate_positive_words^2                                  -1.2107      0.576     -2.101      0.036      -2.340      -0.081
# global_rate_positive_words global_rate_negative_words          0.1546      0.261      0.592      0.554      -0.358       0.667
# global_rate_positive_words rate_positive_words                -3.6096      2.529     -1.427      0.154      -8.567       1.348
# global_rate_positive_words rate_negative_words                 1.7194      1.558      1.104      0.270      -1.334       4.773
# global_rate_positive_words avg_positive_polarity               1.8174      2.738      0.664      0.507      -3.549       7.184
# global_rate_positive_words min_positive_polarity               2.3866      2.510      0.951      0.342      -2.534       7.307
# global_rate_positive_words max_positive_polarity              -4.9505      2.550     -1.941      0.052      -9.949       0.048
# global_rate_positive_words avg_negative_polarity               1.2519      1.593      0.786      0.432      -1.870       4.374
# global_rate_positive_words min_negative_polarity              -1.0439      2.410     -0.433      0.665      -5.768       3.681
# global_rate_positive_words max_negative_polarity               1.4142      2.603      0.543      0.587      -3.687       6.515
# global_rate_positive_words title_subjectivity                 -2.3270      1.933     -1.204      0.229      -6.116       1.462
# global_rate_positive_words title_sentiment_polarity            0.0366      2.366      0.015      0.988      -4.600       4.673
# global_rate_positive_words abs_title_subjectivity              1.9443      2.077      0.936      0.349      -2.126       6.015
# global_rate_positive_words abs_title_sentiment_polarity        4.3621      2.369      1.841      0.066      -0.281       9.005
# global_rate_negative_words^2                                  -0.0083      0.333     -0.025      0.980      -0.661       0.644
# global_rate_negative_words rate_positive_words                 1.7194      1.558      1.104      0.270      -1.334       4.773
# global_rate_negative_words rate_negative_words                -2.3580      1.847     -1.277      0.202      -5.978       1.262
# global_rate_negative_words avg_positive_polarity               1.1263      2.206      0.511      0.610      -3.197       5.449
# global_rate_negative_words min_positive_polarity               0.3715      1.588      0.234      0.815      -2.741       3.484
# global_rate_negative_words max_positive_polarity               0.6005      3.759      0.160      0.873      -6.767       7.968
# global_rate_negative_words avg_negative_polarity              -1.1081      1.654     -0.670      0.503      -4.350       2.134
# global_rate_negative_words min_negative_polarity              -4.2528      3.436     -1.238      0.216     -10.988       2.482
# global_rate_negative_words max_negative_polarity               0.1396      1.041      0.134      0.893      -1.901       2.180
# global_rate_negative_words title_subjectivity                  2.5368      2.636      0.962      0.336      -2.630       7.704
# global_rate_negative_words title_sentiment_polarity           -2.6558      4.065     -0.653      0.514     -10.624       5.313
# global_rate_negative_words abs_title_subjectivity             -1.1003      1.370     -0.803      0.422      -3.786       1.586
# global_rate_negative_words abs_title_sentiment_polarity        3.2183      1.677      1.919      0.055      -0.069       6.506
# rate_positive_words^2                                          0.3626      0.264      1.375      0.169      -0.154       0.879
# rate_positive_words rate_negative_words                        0.1562      0.222      0.704      0.481      -0.278       0.591
# rate_positive_words avg_positive_polarity                      0.4227      0.723      0.585      0.559      -0.994       1.840
# rate_positive_words min_positive_polarity                      0.3602      0.559      0.645      0.519      -0.735       1.455
# rate_positive_words max_positive_polarity                      0.0540      0.279      0.194      0.846      -0.492       0.600
# rate_positive_words avg_negative_polarity                      0.4992      0.906      0.551      0.582      -1.277       2.276
# rate_positive_words min_negative_polarity                     -0.1051      0.375     -0.280      0.779      -0.841       0.631
# rate_positive_words max_negative_polarity                     -0.6816      0.712     -0.957      0.338      -2.077       0.714
# rate_positive_words title_subjectivity                        -0.0593      0.228     -0.260      0.795      -0.507       0.388
# rate_positive_words title_sentiment_polarity                   0.0875      0.242      0.361      0.718      -0.387       0.562
# rate_positive_words abs_title_subjectivity                    -0.3592      0.283     -1.267      0.205      -0.915       0.196
# rate_positive_words abs_title_sentiment_polarity              -0.3937      0.326     -1.208      0.227      -1.032       0.245
# rate_negative_words^2                                         -0.2433      0.298     -0.815      0.415      -0.828       0.342
# rate_negative_words avg_positive_polarity                     -0.8237      0.773     -1.065      0.287      -2.339       0.692
# rate_negative_words min_positive_polarity                     -0.0019      0.619     -0.003      0.998      -1.215       1.211
# rate_negative_words max_positive_polarity                      0.4407      0.323      1.364      0.173      -0.193       1.074
# rate_negative_words avg_negative_polarity                      1.0614      0.956      1.111      0.267      -0.811       2.934
# rate_negative_words min_negative_polarity                     -0.1972      0.395     -0.500      0.617      -0.971       0.576
# rate_negative_words max_negative_polarity                      0.0160      0.761      0.021      0.983      -1.475       1.507
# rate_negative_words title_subjectivity                        -0.5498      0.261     -2.104      0.035      -1.062      -0.038
# rate_negative_words title_sentiment_polarity                  -0.2279      0.279     -0.817      0.414      -0.775       0.319
# rate_negative_words abs_title_subjectivity                    -0.6947      0.321     -2.166      0.030      -1.323      -0.066
# rate_negative_words abs_title_sentiment_polarity               0.4262      0.365      1.169      0.242      -0.288       1.141
# avg_positive_polarity^2                                        0.7770      1.390      0.559      0.576      -1.948       3.502
# avg_positive_polarity min_positive_polarity                    0.6304      2.022      0.312      0.755      -3.332       4.593
# avg_positive_polarity max_positive_polarity                    0.0800      0.815      0.098      0.922      -1.517       1.677
# avg_positive_polarity avg_negative_polarity                    0.9728      2.130      0.457      0.648      -3.203       5.148
# avg_positive_polarity min_negative_polarity                    0.1462      0.848      0.172      0.863      -1.517       1.809
# avg_positive_polarity max_negative_polarity                   -0.5419      1.666     -0.325      0.745      -3.807       2.723
# avg_positive_polarity title_subjectivity                      -0.1258      0.479     -0.263      0.793      -1.065       0.814
# avg_positive_polarity title_sentiment_polarity                -0.1404      0.425     -0.330      0.741      -0.974       0.693
# avg_positive_polarity abs_title_subjectivity                  -0.4908      0.628     -0.781      0.435      -1.722       0.740
# avg_positive_polarity abs_title_sentiment_polarity             0.3470      0.669      0.519      0.604      -0.964       1.658
# min_positive_polarity^2                                        0.4236      1.027      0.412      0.680      -1.589       2.437
# min_positive_polarity max_positive_polarity                   -0.6198      0.735     -0.843      0.399      -2.061       0.821
# min_positive_polarity avg_negative_polarity                    1.0915      1.919      0.569      0.569      -2.669       4.852
# min_positive_polarity min_negative_polarity                   -0.6643      0.778     -0.854      0.393      -2.189       0.861
# min_positive_polarity max_negative_polarity                   -0.2796      1.424     -0.196      0.844      -3.070       2.511
# min_positive_polarity title_subjectivity                       0.1411      0.402      0.351      0.726      -0.647       0.929
# min_positive_polarity title_sentiment_polarity                 0.0231      0.360      0.064      0.949      -0.683       0.729
# min_positive_polarity abs_title_subjectivity                   0.0640      0.543      0.118      0.906      -1.001       1.129
# min_positive_polarity abs_title_sentiment_polarity            -0.3968      0.577     -0.688      0.491      -1.527       0.734
# max_positive_polarity^2                                       -0.2445      0.213     -1.147      0.251      -0.662       0.173
# max_positive_polarity avg_negative_polarity                   -0.7773      0.683     -1.138      0.255      -2.115       0.561
# max_positive_polarity min_negative_polarity                    0.2806      0.256      1.098      0.272      -0.220       0.782
# max_positive_polarity max_negative_polarity                    0.3227      0.566      0.570      0.569      -0.787       1.433
# max_positive_polarity title_subjectivity                       0.2290      0.157      1.463      0.143      -0.078       0.536
# max_positive_polarity title_sentiment_polarity                 0.0528      0.146      0.361      0.718      -0.234       0.340
# max_positive_polarity abs_title_subjectivity                  -0.0178      0.204     -0.088      0.930      -0.418       0.382
# max_positive_polarity abs_title_sentiment_polarity            -0.3062      0.233     -1.311      0.190      -0.764       0.151
# avg_negative_polarity^2                                        0.7310      1.292      0.566      0.572      -1.802       3.264
# avg_negative_polarity min_negative_polarity                    0.1781      0.831      0.214      0.830      -1.452       1.808
# avg_negative_polarity max_negative_polarity                   -2.4273      2.157     -1.126      0.260      -6.654       1.800
# avg_negative_polarity title_subjectivity                       0.2763      0.434      0.636      0.525      -0.575       1.128
# avg_negative_polarity title_sentiment_polarity                 0.1100      0.362      0.304      0.761      -0.599       0.819
# avg_negative_polarity abs_title_subjectivity                   0.4167      0.575      0.724      0.469      -0.711       1.545
# avg_negative_polarity abs_title_sentiment_polarity            -0.9251      0.597     -1.549      0.121      -2.096       0.246
# min_negative_polarity^2                                       -0.1069      0.188     -0.568      0.570      -0.476       0.262
# min_negative_polarity max_negative_polarity                    0.9690      0.852      1.138      0.255      -0.700       2.638
# min_negative_polarity title_subjectivity                      -0.1751      0.160     -1.094      0.274      -0.489       0.139
# min_negative_polarity title_sentiment_polarity                -0.0257      0.139     -0.184      0.854      -0.299       0.247
# min_negative_polarity abs_title_subjectivity                  -0.0466      0.214     -0.218      0.827      -0.465       0.372
# min_negative_polarity abs_title_sentiment_polarity             0.5514      0.225      2.447      0.014       0.110       0.993
# max_negative_polarity^2                                        0.5050      1.108      0.456      0.649      -1.667       2.677
# max_negative_polarity title_subjectivity                       0.0946      0.362      0.262      0.794      -0.614       0.804
# max_negative_polarity title_sentiment_polarity                -0.0043      0.301     -0.014      0.989      -0.594       0.585
# max_negative_polarity abs_title_subjectivity                   0.0639      0.481      0.133      0.894      -0.879       1.007
# max_negative_polarity abs_title_sentiment_polarity             0.0861      0.507      0.170      0.865      -0.908       1.080
# title_subjectivity^2                                          -0.2499      0.132     -1.899      0.058      -0.508       0.008
# title_subjectivity title_sentiment_polarity                   -0.0867      0.127     -0.683      0.494      -0.335       0.162
# title_subjectivity abs_title_subjectivity                      0.2761      0.210      1.314      0.189      -0.136       0.688
# title_subjectivity abs_title_sentiment_polarity               -0.0242      0.164     -0.148      0.883      -0.345       0.297
# title_sentiment_polarity^2                                     0.1876      0.058      3.244      0.001       0.074       0.301
# title_sentiment_polarity abs_title_subjectivity                0.1697      0.182      0.934      0.350      -0.187       0.526
# title_sentiment_polarity abs_title_sentiment_polarity         -0.2022      0.100     -2.018      0.044      -0.399      -0.006
# abs_title_subjectivity^2                                      -0.1766      0.181     -0.976      0.329      -0.531       0.178
# abs_title_subjectivity abs_title_sentiment_polarity           -0.1148      0.251     -0.457      0.648      -0.607       0.378
# abs_title_sentiment_polarity^2                                 0.1876      0.058      3.244      0.001       0.074       0.301
# ==============================================================================
# Omnibus:                     6970.944   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18116.813
# Skew:                           0.967   Prob(JB):                         0.00
# Kurtosis:                       5.688   Cond. No.                     7.95e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.95e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Regression tree for identifying important predictors
tree = DecisionTreeRegressor(random_state=123)
tree.fit(X, y)

feature_importances = pd.Series(tree.feature_importances_, index=X.columns).sort_values(ascending=False)
print("Top Predictors from the Regression Tree:")
print(feature_importances.head(10))
# Out:
# Top Predictors from the Regression Tree:
# kw_avg_avg                    0.096617
# timedelta                     0.043315
# self_reference_avg_sharess    0.040367
# kw_max_avg                    0.035127
# average_token_length          0.030978
# LDA_02                        0.030296
# n_unique_tokens               0.030180
# global_subjectivity           0.029307
# LDA_01                        0.028663
# num_hrefs                     0.028431
# dtype: float64

# %%
# Visualize top predictors
top_features = feature_importances.index[:5]

for feature in top_features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df[feature], y=df[target])
    plt.title(f'{feature} vs Shares', fontsize=14)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Shares', fontsize=12)
    plt.grid()
    plt.show()

# %% [markdown]
# Linear Regression with Tuning

# %%
X_final = X[top_features]
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.3, random_state=123)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print("Test MSE:", mean_squared_error(y_test, y_pred))
print("Test R²:", r2_score(y_test, y_pred))
# Out:
# Test MSE: 0.8137672498940893
# Test R²: 0.0710109894570532

# %%
# LASSO Regression to tune ans select features
alphas = np.logspace(-3, 1, 50)
lasso = Lasso(random_state=123)
grid = GridSearchCV(lasso, {'alpha': alphas}, cv=5, scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)

best_alpha = grid.best_params_['alpha']
print("Best alpha for LASSO:", best_alpha)

lasso_best = Lasso(alpha=best_alpha, random_state=123)
lasso_best.fit(X_train, y_train)

y_pred_lasso = lasso_best.predict(X_test)
print("Test MSE (LASSO):", mean_squared_error(y_test, y_pred_lasso))
print("Test R² (LASSO):", r2_score(y_test, y_pred_lasso))
# Out:
# Best alpha for LASSO: 0.001
# Test MSE (LASSO): 0.81374679087693
# Test R² (LASSO): 0.07103434527790997

# %% [markdown]
# Regression Tree Modeling

# %%
path = tree.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas

ccp_alphas_sampled = np.linspace(ccp_alphas.min(), ccp_alphas.max(), num=10)

# Cross-validation to find the best alpha
mse_scores = []
for alpha in ccp_alphas_sampled:
    temp_tree = DecisionTreeRegressor(random_state=123, ccp_alpha=alpha)
    mse = -cross_val_score(temp_tree, X_train, y_train, cv=3, scoring='neg_mean_squared_error').mean()
    mse_scores.append(mse)

best_alpha = ccp_alphas_sampled[np.argmin(mse_scores)]

pruned_tree = DecisionTreeRegressor(random_state=123, ccp_alpha=best_alpha)
pruned_tree.fit(X_train, y_train)

y_pred_tree = pruned_tree.predict(X_test)
print("Test MSE (Pruned Tree):", mean_squared_error(y_test, y_pred_tree))
print("Test R² (Pruned Tree):", r2_score(y_test, y_pred_tree))
# Out:
# Test MSE (Pruned Tree): 0.802137315515714
# Test R² (Pruned Tree): 0.08428761275720753

# %%
def prune_tree(tree, X_train, y_train, ccp_alphas_sampled, best_alpha):
    pruned_tree = DecisionTreeRegressor(random_state=123, ccp_alpha=best_alpha)
    pruned_tree.fit(X_train, y_train)
    return pruned_tree

pruned_trees = []
for i in range(50):
    tree = DecisionTreeRegressor(random_state=123 + i)
    pruned_tree = prune_tree(tree, X_train, y_train, ccp_alphas_sampled, best_alpha)
    pruned_trees.append(pruned_tree)

rf_predictions = np.mean([tree.predict(X_test) for tree in pruned_trees], axis=0)

print("Test MSE (Pruned Random Forest):", mean_squared_error(y_test, rf_predictions))
print("Test R² (Pruned Random Forest):", r2_score(y_test, rf_predictions))
# Out:
# Test MSE (Pruned Random Forest): 211742145.7569296
# Test R² (Pruned Random Forest): 0.006866674112999793

# %%
# Model Comparison
results = {
    "Linear": [mean_squared_error(y_test, y_pred), r2_score(y_test, y_pred)],
    "LASSO": [mean_squared_error(y_test, y_pred_lasso), r2_score(y_test, y_pred_lasso)],
    "Pruned Tree": [mean_squared_error(y_test, y_pred_tree), r2_score(y_test, y_pred_tree)],
    "Random Forest": [mean_squared_error(y_test, y_pred_rf), r2_score(y_test, y_pred_rf)]
}

results_df = pd.DataFrame(results, index=["MSE", "R²"])
print(results_df)
